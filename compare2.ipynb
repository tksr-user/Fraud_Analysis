# %%
import mlflow
import pandas as pd
from gpt4all import GPT4All
# Connect to local MLflow server
mlflow.set_tracking_uri("http://127.0.0.1:5000")
experiment = mlflow.get_experiment_by_name("Fraud_Detection_Comparison")

# Get all runs from the experiment
df_runs = mlflow.search_runs(experiment_ids=[experiment.experiment_id])

# Preview your data
print(df_runs[[
    "run_id", "params.model", 
    "metrics.accuracy", "metrics.precision", "metrics.recall",
]])
def create_comparison_prompt(df, target_run_id):
    prompt = f"Compare the following ML models to target run ID **{target_run_id}** using accuracy, precision, recall, and f1_score.\n\n"
    
    for idx, row in df.iterrows():
        prompt += f"Model {idx + 1}:\n"
        prompt += f" - Run ID: {row['run_id']}\n"
        prompt += f" - Model Type: {row.get('params.model', 'N/A')}\n"
        
        for metric in ["accuracy", "precision", "recall"]:
            col_name = f"metrics.{metric}"
            if col_name in row and pd.notnull(row[col_name]):
                prompt += f" - {metric.capitalize()}: {row[col_name]:.4f}\n"
        prompt += "\n"
        
    prompt += f"Now rank these models from best to worst compared to the target model ({target_run_id}). Give a short explanation."
    return prompt
# Choose a specific run ID to compare others against (e.g., best Logistic Regression model)
target_run_id = df_runs.iloc[0]["run_id"]  # or pick based on best f1_score, etc.

prompt = create_comparison_prompt(df_runs, target_run_id)
print(prompt)  # Optional: see what you're sending to GPT


# Load your local model — path must match your installed model
model = GPT4All("Llama-3.2-3B-Instruct-Q4_0.gguf")

# Generate response from prompt
prompt = "Compare model A (accuracy=0.93) with model B (accuracy=0.89). Which one is better and why?"
response = model.generate(prompt)

print("AI Agent Response:")
print(response)
# Out:
#                                run_id        params.model  metrics.accuracy  \
# 0    2f080b7d8ddb4b1f9e7434336e4cad97                 SVC          0.999000
# 1    8367310345f2407aa2ee94cbb1c45d22        RandomForest          0.999000
# 2    5993360bb554416da62b9b595775d67b  LogisticRegression          0.998333
# 3    b3e2f5192700497cae7fc54f27332dbf                 SVC          0.998000
# 4    8c2caeccca5844a8b43abf52e7ba9a33        RandomForest          0.998333
# ..                                ...                 ...               ...
# 251  dd23fe8ddbad4daa9c0b1653bd6b4b3f                None               NaN
# 252  1bd8990ddc2c48eea080154b98626d03                None               NaN
# 253  6f547ccf19724a27b999fe9e6fd600be                None               NaN
# 254  4dc6a4af64924d27a7c9bb0eb9c80ee8                None               NaN
# 255  3e5d782a089d4d84bfee96aff5f944c3                None               NaN
#
#      metrics.precision  metrics.recall
# 0                  1.0        0.500000
# 1                  1.0        0.500000
# 2                  1.0        0.166667
# 3                  0.0        0.000000
# 4                  1.0        0.166667
# ..                 ...             ...
# 251                NaN             NaN
# 252                NaN             NaN
# 253                NaN             NaN
# 254                NaN             NaN
# 255                NaN             NaN
#
# [256 rows x 5 columns]
# Compare the following ML models to target run ID **2f080b7d8ddb4b1f9e7434336e4cad97** using accuracy, precision, recall, and f1_score.
#
# Model 1:
#  - Run ID: 2f080b7d8ddb4b1f9e7434336e4cad97
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 2:
#  - Run ID: 8367310345f2407aa2ee94cbb1c45d22
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 3:
#  - Run ID: 5993360bb554416da62b9b595775d67b
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 1.0000
#  - Recall: 0.1667
#
# Model 4:
#  - Run ID: b3e2f5192700497cae7fc54f27332dbf
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 5:
#  - Run ID: 8c2caeccca5844a8b43abf52e7ba9a33
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 1.0000
#  - Recall: 0.1667
#
# Model 6:
#  - Run ID: f077b0346c1f45139912055cf4ac31ea
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9973
#  - Precision: 0.2500
#  - Recall: 0.1667
#
# Model 7:
#  - Run ID: 97a61082d08545c0a0b198327ceda95c
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 8:
#  - Run ID: 1370408e515e4dc4b50773e00726006f
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6667
#
# Model 9:
#  - Run ID: 583969250166404aa360a0eb8556678f
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9977
#  - Precision: 0.3333
#  - Recall: 0.1667
#
# Model 10:
#  - Run ID: 1d24d4f983ea4876ad9e4703683a320d
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 11:
#  - Run ID: e890af8e3fac4afe923113c7184069a9
#  - Model Type: RandomForest
#  - Accuracy: 1.0000
#  - Precision: 1.0000
#  - Recall: 1.0000
#
# Model 12:
#  - Run ID: ef9616f5b3c849cd84b37efd056af991
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 13:
#  - Run ID: cab9a22d9d3c425e84362491e074557e
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 14:
#  - Run ID: 4bf37f7b01b243ff97786a728d90623c
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 15:
#  - Run ID: daafa31773514a73ab840b14d480af09
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 16:
#  - Run ID: a4a2f1fe5c0645f899a80078afed8f59
#  - Model Type: SVC
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 17:
#  - Run ID: 84c5844d47004021b540fae948e8365a
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 18:
#  - Run ID: 6b595e256a5e4cfd9ea2132cab9c02a2
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.4286
#  - Recall: 0.7500
#
# Model 19:
#  - Run ID: f832cb9e25d249c7b4a2566c632f2ebd
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 20:
#  - Run ID: b75734a0036744b5ad7a830b1934dbd3
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 21:
#  - Run ID: d6f8ef5e2c0344bfa783851b89842152
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 22:
#  - Run ID: f3048535160649d8869d2ea57682d7cc
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 23:
#  - Run ID: f7f3cbe410284793a6e845075e8fbb82
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 24:
#  - Run ID: e40123d5bdf54bb7bd5187cdef24fb84
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 25:
#  - Run ID: 5ae1d9efd46c47a0910faac0e263d32f
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 26:
#  - Run ID: 4b5e2356ad7c451fb0bfa8a4126722eb
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 27:
#  - Run ID: 6e012864a5df4c44845db2efab6dbd73
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 28:
#  - Run ID: 42f8a5c87847472fbbe504bc6375689a
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.5000
#
# Model 29:
#  - Run ID: 8c211e5b4e9b4656986cc695d464839e
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 30:
#  - Run ID: 77fa698ed2244340ba7f3b08ce754af6
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 31:
#  - Run ID: 71bc6e0d7de848f98594c67117685863
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 32:
#  - Run ID: 99513977168347ca8d603f07b329b921
#  - Model Type: RandomForest
#  - Accuracy: 1.0000
#  - Precision: 1.0000
#  - Recall: 1.0000
#
# Model 33:
#  - Run ID: f6603706b4514db89146dec6abee530b
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 34:
#  - Run ID: 0a6677c8d1e244d7a023d1917a20e572
#  - Model Type: SVC
#  - Accuracy: 0.9997
#  - Precision: 0.8000
#  - Recall: 1.0000
#
# Model 35:
#  - Run ID: 52141af9ea3447508be9752924d1664f
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 36:
#  - Run ID: f11340c737884e34ac207706173dc739
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 37:
#  - Run ID: 4f93dbf22db34815b4ba4c2d45a42a55
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 38:
#  - Run ID: 6a798f0c9f6b456684444c10c0ca3973
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 39:
#  - Run ID: a8d9029418ec458f80c0a112a97d0bad
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 40:
#  - Run ID: 326f334165894fa7ba1c5d1dade114e2
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 41:
#  - Run ID: 99643abd33f84c20ba8dcc020e49b208
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 42:
#  - Run ID: e457aa24bf704bc390eb4d74bc4fe4f5
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 43:
#  - Run ID: 93b705abf1b2426e90ad9cedbb96b960
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 44:
#  - Run ID: b24e2bf2a9e341ceb8fb0a322f851cdb
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 45:
#  - Run ID: 6b8b0397ccbd40ad9186e8935ecac17c
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 46:
#  - Run ID: bbbd9c564b294945866cca34da4f0216
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 47:
#  - Run ID: 93234f87bb694134ab6406e955ab96d1
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 48:
#  - Run ID: 1f52ff76e8c84c98bd8305b491cb3501
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 49:
#  - Run ID: c516251d49dc41e887b409cfa1e30430
#  - Model Type: SVC
#  - Accuracy: 0.9977
#  - Precision: 0.2500
#  - Recall: 0.2000
#
# Model 50:
#  - Run ID: f4ba92225d2e41a09a69f656bf10ffe7
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 51:
#  - Run ID: e07a8bd40d0641f4a7b415c0ae1544ae
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 52:
#  - Run ID: c5010643d8ba41288362cdc2491821ea
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6000
#  - Recall: 0.6000
#
# Model 53:
#  - Run ID: bad69987c20c4e19a86fd76fb35bb447
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.2000
#
# Model 54:
#  - Run ID: e38756e35e3b4c0697e9c707c592b0e0
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 55:
#  - Run ID: da120a31f66649488c45bddc27e4b438
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 56:
#  - Run ID: dca763c7284946f4896c3105a179f160
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 57:
#  - Run ID: d00eb9fa7a5749c8b8a660363f237a75
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 58:
#  - Run ID: e05956016e1147958e447df22d71607b
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 59:
#  - Run ID: 9f965178264442ea98f14040bbf097c3
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 60:
#  - Run ID: 68b024b49768499f8052556181bfc4dd
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.3333
#  - Recall: 0.2500
#
# Model 61:
#  - Run ID: ee359d57b7224110b6f29be68cbe2d6d
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 62:
#  - Run ID: bd922d00878945a9b5d9a1b0d839a7a6
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.7500
#  - Recall: 0.7500
#
# Model 63:
#  - Run ID: c355c076c6c349dcbb9eb07abb7a56fa
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 64:
#  - Run ID: 96108f5ee6534d2eae9fc1b90c5435d8
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.8000
#  - Recall: 0.6667
#
# Model 65:
#  - Run ID: fc0a0c4d97bc4283a9bd5c2da89c5287
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.8333
#
# Model 66:
#  - Run ID: 6509c39bcc914aa6a0247e0fa4b5c51e
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.6667
#  - Recall: 0.3333
#
# Model 67:
#  - Run ID: b7880eedabca430fafe2b935170e2600
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 68:
#  - Run ID: 0297e4ef68034b1484629a701e673666
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 69:
#  - Run ID: 6d04108e306440248959905c264ff68e
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9973
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 70:
#  - Run ID: fe9d5be0c11248a497abb5a164d9eb5a
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 71:
#  - Run ID: a0089d2693494331a3d982b5047f3993
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 72:
#  - Run ID: 7a622286a72c44c88a0317f56e1a83e4
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 73:
#  - Run ID: 7b50d82c4cd34b4a967dad8a28859829
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 74:
#  - Run ID: 49da5e76ba014775a8e5a385a2702a1f
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 75:
#  - Run ID: 4cd850ca82d34b79819761c94bece328
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 76:
#  - Run ID: 40ae360268b343a2a3ab1a5de7482997
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 77:
#  - Run ID: 086e77276776439586a3418be61f4b5e
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.2000
#
# Model 78:
#  - Run ID: 791d5aac3f704a048ae0993e799783d7
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 79:
#  - Run ID: 151959d586b14ad3ab6816a02d821c13
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 80:
#  - Run ID: 307c17a0835b4099aa1ccecb590cc61d
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 81:
#  - Run ID: e79cd611b21b4e0fb45be811f9dc626a
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 82:
#  - Run ID: f3bfb5107e6f468d80bd381b539e502f
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 83:
#  - Run ID: b4062e7fc6f746dda7e39cd267177271
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 84:
#  - Run ID: e2af565e009b4504872ccb47a7ee18cf
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 85:
#  - Run ID: 700d68e90e4948fca55e05e8c48abf6e
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 86:
#  - Run ID: fc53fbc2613b4359892e83c1d673b680
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.6667
#  - Recall: 0.3333
#
# Model 87:
#  - Run ID: fdc191650de440ac9f3bcf5ea1b48481
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 88:
#  - Run ID: 4a5bc047e6e74f6c91a2603b78120520
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 89:
#  - Run ID: 4e14ba0ecc4b4f699f4c7dbbf8fd9ff6
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 90:
#  - Run ID: 02b0be6a02d14af58d424825e39fbea7
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 91:
#  - Run ID: bf25d2a4ff6b4509b3f320c49bc01485
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 92:
#  - Run ID: b84cb8efaf6a4f4d8c205d9e293bb1aa
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 93:
#  - Run ID: e26a3895a5b74c339523f5ff9ae42a15
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6667
#
# Model 94:
#  - Run ID: 34992ac58ff043bfa090232addfc9e4b
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 1.0000
#  - Recall: 0.1667
#
# Model 95:
#  - Run ID: 54f08a9d471c4c2f907fd0fca84ffb4b
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 96:
#  - Run ID: 43341fc1080f483f8f18f4d52cc207b4
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 97:
#  - Run ID: 72bd52dd6dca404bb3e3c13fe4b5cb10
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9973
#  - Precision: 0.2500
#  - Recall: 0.1667
#
# Model 98:
#  - Run ID: baea3ba633a64a1cb71d66d9cca04dbe
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 99:
#  - Run ID: 64697c69334d40e69112a100c0f78e35
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 100:
#  - Run ID: b509ae0264424c32b3d698bd60858346
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9977
#  - Precision: 0.3333
#  - Recall: 0.1667
#
# Model 101:
#  - Run ID: 06564bb4f4504f28a7db88f602da865f
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 102:
#  - Run ID: 963d843fa9c84b0d87fa67b100a597e7
#  - Model Type: RandomForest
#  - Accuracy: 1.0000
#  - Precision: 1.0000
#  - Recall: 1.0000
#
# Model 103:
#  - Run ID: 62841ceae6e84138a15c0bf71c8d5a9f
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 104:
#  - Run ID: 9c24b95dece04cc8a22519a53aa4a47c
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 105:
#  - Run ID: e324d519597d408bb991074403acc8af
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 106:
#  - Run ID: 4ffe67fb65f744f2972150b435fbf0e6
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 107:
#  - Run ID: 125b8d04d14b41c3a2b06f00b0876511
#  - Model Type: SVC
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 108:
#  - Run ID: 97be16879d144517b8f62660d91b61db
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 109:
#  - Run ID: 88f5a95d05364e03a5e559f834beb19e
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.4286
#  - Recall: 0.7500
#
# Model 110:
#  - Run ID: 7811e9da0aee4381b9bbba0eeb4404fd
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 111:
#  - Run ID: e1c917ffc07c4e3588cc20d8ef6f44ba
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 112:
#  - Run ID: 8cb83d29c4ae479083816cbfca67f0ae
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 113:
#  - Run ID: 10d62e694893401b9479bee0ccbe40e8
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 114:
#  - Run ID: 1a606a2b4c714acfacd76dc6c0db3392
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 115:
#  - Run ID: 6a7203825a4f49faa5e9b2dc4b6eb1c4
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 116:
#  - Run ID: 94a5cbc7f26642bd878beb0bec1dd261
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 117:
#  - Run ID: a6c4bafb41da482699457228e8abfa4b
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 118:
#  - Run ID: 9c3852a6c7ae47f7bffe1f71b894dc35
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.2500
#
# Model 119:
#  - Run ID: e8f1f2e882164eb69042c410530de2a9
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.5000
#
# Model 120:
#  - Run ID: 63e1d0f17a0e42ad9aefed34aed7a2af
#  - Model Type: RandomForest
#  - Accuracy: 1.0000
#  - Precision: 1.0000
#  - Recall: 1.0000
#
# Model 121:
#  - Run ID: fc6e97218e35472ca26a01a36a86bd6b
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 122:
#  - Run ID: df7b59a37f4f4074baf5984c58fa0162
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 123:
#  - Run ID: c260f47474094277b27039897030b647
#  - Model Type: RandomForest
#  - Accuracy: 0.9997
#  - Precision: 1.0000
#  - Recall: 0.7500
#
# Model 124:
#  - Run ID: b7d0a8679ec548d28ea10b13522ba151
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 125:
#  - Run ID: 44f0344d22e34fe3a39b843f9496bb05
#  - Model Type: SVC
#  - Accuracy: 0.9997
#  - Precision: 0.8000
#  - Recall: 1.0000
#
# Model 126:
#  - Run ID: 50feff6ffdf14fa69fa5888fb546500e
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 127:
#  - Run ID: 73848e58637a46b8a62f86fd6ef114ad
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 128:
#  - Run ID: eddffba5f3de4d51952f23cfaec43653
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 129:
#  - Run ID: d3fe1892b9d747949ce5a99fad9a2a08
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 130:
#  - Run ID: d979d5d4ac76406ba3e6adb7ad0cf3b0
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 131:
#  - Run ID: 62a9c77c8b494b4b8c16512ca30af38d
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 132:
#  - Run ID: 4e8e5ab58afd4dee9d1a7358d8ec534e
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 133:
#  - Run ID: 4bcc9c60bd824ecca8cab185d6364ca6
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 134:
#  - Run ID: 8999616d32094053bcc18283d48e4d94
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 135:
#  - Run ID: 17650942d6cd4bc9ac574efe72b2d5b6
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 136:
#  - Run ID: 5dd44a4849034e349fd2c72321ef784d
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 137:
#  - Run ID: bfa729a0f0264ba1ab972dae986cfcb9
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 138:
#  - Run ID: b6424244c2144e7faa05c94b83a20501
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.7500
#  - Recall: 0.6000
#
# Model 139:
#  - Run ID: 6687fb35d6ef4c03bf928480c015c32c
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 140:
#  - Run ID: 9b357f3318034c8b870bf96c891d8e01
#  - Model Type: SVC
#  - Accuracy: 0.9977
#  - Precision: 0.2500
#  - Recall: 0.2000
#
# Model 141:
#  - Run ID: 748280b2b3e143e19e24dbca0b4af8f1
#  - Model Type: RandomForest
#  - Accuracy: 0.9977
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 142:
#  - Run ID: e9e3f7e5ecbe43978fcdfab5d42e966c
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 143:
#  - Run ID: 830e66067efe4b1fac77b8730136819c
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6000
#  - Recall: 0.6000
#
# Model 144:
#  - Run ID: e52715e0feb140aeaaa945562f3872b3
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 145:
#  - Run ID: 58a4a1569e4e48948bbed2c709a9aff2
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 146:
#  - Run ID: 492ffad22a724b0b8cbc54b19dc03147
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 147:
#  - Run ID: f5602442cb2349e0ba91fc3f2fc668fc
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.6000
#  - Recall: 0.7500
#
# Model 148:
#  - Run ID: 3f9edf29f6674884b4bba85734ab6643
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 149:
#  - Run ID: cec1af513bc246caafa175c4412cdb12
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 150:
#  - Run ID: a8d5810818e44c898408202290a8b4bc
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.5000
#
# Model 151:
#  - Run ID: 39747b8cc6d64633a2368183ccfb7cbb
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.3333
#  - Recall: 0.2500
#
# Model 152:
#  - Run ID: 5e2d292604b8473494003e7ee0a2b3ae
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 153:
#  - Run ID: ffad0140c17a4494a700cb58c14a02f5
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 0.7500
#  - Recall: 0.7500
#
# Model 154:
#  - Run ID: 38db61770175469886138afa9605c842
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 155:
#  - Run ID: 814f88e5c19a439abcab2e871702432e
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.8000
#  - Recall: 0.6667
#
# Model 156:
#  - Run ID: fce3e67d949040fbb700d24708f5b608
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6667
#
# Model 157:
#  - Run ID: b5264e3f29934cbdac639c810b69bb03
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.6667
#  - Recall: 0.3333
#
# Model 158:
#  - Run ID: 75d1a545d0304d9db8101771a4218796
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 159:
#  - Run ID: 5b4f85c3c5c74e359b14d31cba96d67d
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 1.0000
#  - Recall: 0.3333
#
# Model 160:
#  - Run ID: 4d5426efe55b4fb7818856f6d6c03cfa
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9973
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 161:
#  - Run ID: 48b45ad0fbe04540a8da2accf3643701
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 162:
#  - Run ID: 205605dff9e34e169d346c83ae094004
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 163:
#  - Run ID: 67d40a005ef246f38cbff1f0b1e06464
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 164:
#  - Run ID: 77d090e9dcf14aa8baaf0741de4e83e3
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 165:
#  - Run ID: ded4162435cb473e9b509f8ba8f5e578
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 166:
#  - Run ID: 2049d8676e054dc2aa457efab8c324ac
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 167:
#  - Run ID: 33f15e8cd9244b229af6166d36d12ec5
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 168:
#  - Run ID: 60a88eb102064cfb859e0422f9db247b
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 169:
#  - Run ID: 72f4aa405aa54e6699a2e288a89dcbfc
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 170:
#  - Run ID: 473b2db9875348c0a0a326c785035bf3
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 171:
#  - Run ID: b254234a51f943d49fa9fbaf634c9023
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 172:
#  - Run ID: a0d3f6be05324698932b6298d761a82e
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 173:
#  - Run ID: ea7b13bccba54219ac0e42147957ea2b
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 174:
#  - Run ID: 49329c2bd2a74d8dbdc88512818d92a1
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.8000
#  - Recall: 0.6667
#
# Model 175:
#  - Run ID: a8fd5bf5c24f41caa28a570ebd0295f6
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 176:
#  - Run ID: e327d5b121364019a43bb4367774efea
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 177:
#  - Run ID: ec7c019b649b4b17b58acf9e348b481e
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 178:
#  - Run ID: 10d7e8f2e57a4bb6aecdab9444a49d79
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 179:
#  - Run ID: 116f8698efd94cf8997d5bd3dc47f648
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 180:
#  - Run ID: d9de8f5f228e4ad1b9cbc7172f44f345
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.6000
#  - Recall: 0.5000
#
# Model 181:
#  - Run ID: 392e88cc34764ce68500aadf9b291e9d
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 182:
#  - Run ID: a82a3640e1454ab3b4976689e7b652ec
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 183:
#  - Run ID: a8aac0c906b84a318cdf88c33ddfc1e0
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 184:
#  - Run ID: 41d6fc4137dc40b1916dcbdddf2f717c
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9993
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 185:
#  - Run ID: 6bc9eef66d5a49aa841e6f2a56169373
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 186:
#  - Run ID: fcca30cb1d6946588a7f28b608a60fc8
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.7500
#  - Recall: 0.6000
#
# Model 187:
#  - Run ID: eb5217a269944ffdb1639669e83214a2
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 188:
#  - Run ID: a4b25e457f564211bb815832260e15e5
#  - Model Type: SVC
#  - Accuracy: 0.9977
#  - Precision: 0.2500
#  - Recall: 0.2000
#
# Model 189:
#  - Run ID: 6a5869c2b90141c386d3e8d8b4ddf315
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 190:
#  - Run ID: ddc56093571b4e65b8ea783c642cf54d
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 191:
#  - Run ID: c9e5c497aa1d4ca193f1a74c6df51fab
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6000
#  - Recall: 0.6000
#
# Model 192:
#  - Run ID: 27431221d2884263a2f920b7e82620be
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.2000
#
# Model 193:
#  - Run ID: 7be4c774921848778497ab6f3b9a0ce5
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 194:
#  - Run ID: 2340ab4b536d4e8890995054ce2fa5a2
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 195:
#  - Run ID: 5b41c7aa9b5e485fb4b947c7ff2a7fb2
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.6000
#  - Recall: 0.7500
#
# Model 196:
#  - Run ID: d8d5a170e6e14cd5ac4b5cee26f11b4a
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 197:
#  - Run ID: 9c65cfcffe5c45449b6d4f115f8eb707
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 198:
#  - Run ID: 4eb5fc67a17a42599a93dbebe4835f11
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.2500
#
# Model 199:
#  - Run ID: 9d2398290e1c412aa670d7fb3c017b96
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.3333
#  - Recall: 0.2500
#
# Model 200:
#  - Run ID: cf7ba9cd207c44fcb1f1339dea19952d
#  - Model Type: SVC
#  - Accuracy: 0.9993
#  - Precision: 0.6667
#  - Recall: 1.0000
#
# Model 201:
#  - Run ID: 59a9b6b639c6429f8c9e0cf9a0eb5560
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.5000
#
# Model 202:
#  - Run ID: 291fcc7bf0214a0588f00c5172abff5d
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9987
#  - Precision: 0.5000
#  - Recall: 0.5000
#
# Model 203:
#  - Run ID: 177d99ab668d49209413027e2f440196
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.8000
#  - Recall: 0.6667
#
# Model 204:
#  - Run ID: 3987c0b560a84481a3cc813a6df40b83
#  - Model Type: RandomForest
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.5000
#
# Model 205:
#  - Run ID: b31f37b33a9940cc9bb9217dd3f951c4
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.6667
#  - Recall: 0.3333
#
# Model 206:
#  - Run ID: 589e26ff828f4b98a1114d893498f8d0
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 207:
#  - Run ID: 173c704560bb4d01ba325e21923111aa
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 1.0000
#  - Recall: 0.3333
#
# Model 208:
#  - Run ID: 4e208aca5da244a898557463efb4cf88
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9973
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 209:
#  - Run ID: 1fcbedcb989d49308625390ec43532f0
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.0000
#  - Recall: 0.0000
#
# Model 210:
#  - Run ID: 145aefa1160443149049b059467f3971
#  - Model Type: RandomForest
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6667
#
# Model 211:
#  - Run ID: 04137efd44c34d79a3a325fb2eb59b51
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.1667
#
# Model 212:
#  - Run ID: 175b2993ca0146ed9aac24691b3c3a72
#  - Model Type: SVC
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 213:
#  - Run ID: 9d7c07e378784cdb94d60104986ecb31
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.2000
#
# Model 214:
#  - Run ID: 2b0e090ad23848749305a7908b224117
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 215:
#  - Run ID: 76dee40e35d14d489f870694baca09e9
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 216:
#  - Run ID: 58bcf27bd3f645768c11ebf71a212486
#  - Model Type: RandomForest
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 217:
#  - Run ID: b55518eff13344eaaa48781f0af255bd
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 218:
#  - Run ID: 62ef468574fa495c9e8fb302d1454775
#  - Model Type: SVC
#  - Accuracy: 0.9990
#  - Precision: 0.6667
#  - Recall: 0.8000
#
# Model 219:
#  - Run ID: c39e3504cdf24bcb9d612254a7e7938d
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.4000
#
# Model 220:
#  - Run ID: 7d4ac4afeb8e473fbda12d5b0f54e907
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9983
#  - Precision: 0.5000
#  - Recall: 0.4000
#
# Model 221:
#  - Run ID: fabb01707f484a6dbc200917a4fb7138
#  - Model Type: SVC
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 222:
#  - Run ID: 6f4ff6b95330464cb82fc4cbf20c0821
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.7500
#  - Recall: 0.5000
#
# Model 223:
#  - Run ID: da10a7b4cd394c32abb4fa00545e4c55
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 224:
#  - Run ID: eaf945432ae44236a69c494c28e48e17
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 225:
#  - Run ID: 8d2d56497e42481089edaf5521d9fd78
#  - Model Type: RandomForest
#  - Accuracy: 0.9987
#  - Precision: 0.7500
#  - Recall: 0.5000
#
# Model 226:
#  - Run ID: f3b32ad4a9c6499687c905ba5f80a045
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 227:
#  - Run ID: e01ad56d653a44618fce6bc9872ea7d4
#  - Model Type: SVC
#  - Accuracy: 0.9987
#  - Precision: 0.6667
#  - Recall: 0.6667
#
# Model 228:
#  - Run ID: 44236de59843449f9d8085cbdf5e1ac5
#  - Model Type: RandomForest
#  - Accuracy: 0.9983
#  - Precision: 0.6000
#  - Recall: 0.5000
#
# Model 229:
#  - Run ID: 98e98a108a194ceb81be0afff291f4e4
#  - Model Type: LogisticRegression
#  - Accuracy: 0.9980
#  - Precision: 0.5000
#  - Recall: 0.3333
#
# Model 230:
#  - Run ID: 76d33a1df8bd45fea4ea436e975fe2de
#  - Model Type: None
#
# Model 231:
#  - Run ID: 92b65c24d1e842f682ee5bbe9a2078e6
#  - Model Type: None
#  - Accuracy: 0.9500
#
# Model 232:
#  - Run ID: 6f60d07b4a1d4a70bebfdd6b638caecb
#  - Model Type: None
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.4000
#
# Model 233:
#  - Run ID: 1726d09921fa4d178fc74c0d50675aea
#  - Model Type: None
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6000
#
# Model 234:
#  - Run ID: 20b71b7d3df54f1f860843733d6add5c
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 235:
#  - Run ID: b70816424b1d414d9cd71633db67bb26
#  - Model Type: None
#
# Model 236:
#  - Run ID: 9c8610bbc62148ff905c26f561c37513
#  - Model Type: None
#  - Accuracy: 0.9500
#
# Model 237:
#  - Run ID: 80c08f7ea1784ee48bdea2ba42867198
#  - Model Type: None
#
# Model 238:
#  - Run ID: 48e7ddc83cef4f4f96c398439b48b0db
#  - Model Type: None
#  - Accuracy: 0.9500
#
# Model 239:
#  - Run ID: 559afa9fa53542169b26d711001f88ca
#  - Model Type: None
#
# Model 240:
#  - Run ID: 748073edfb1749c086be9a32871d5f4a
#  - Model Type: None
#  - Accuracy: 0.9500
#
# Model 241:
#  - Run ID: e0027c4c95c849dca02e595bd4078a42
#  - Model Type: None
#  - Accuracy: 0.9990
#  - Precision: 1.0000
#  - Recall: 0.4000
#
# Model 242:
#  - Run ID: 1a80903ec40a47318417945867a901b5
#  - Model Type: None
#  - Accuracy: 0.9993
#  - Precision: 1.0000
#  - Recall: 0.6000
#
# Model 243:
#  - Run ID: 8dd4feef061740cd8c2a49b963dbac12
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 244:
#  - Run ID: 823ed05b0ee24884b3c0d8fd80860e37
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 245:
#  - Run ID: 2440b0923f1b470993056c5cb00a079c
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 246:
#  - Run ID: b032f98a2b9c4cf7b67390fecd90f8f5
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 247:
#  - Run ID: 72cbde8082cc4702a696eb640ea5aed9
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 248:
#  - Run ID: 66803e4af6724d91bbe4d1071e993f7a
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 249:
#  - Run ID: 532bb95b08f549c2ada3e58bfd9d66c0
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 250:
#  - Run ID: 634958b83f864490867ae702628d4dca
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 251:
#  - Run ID: 2e0d1e4d1f5d4937b499bd548349108c
#  - Model Type: None
#  - Accuracy: 0.9980
#  - Precision: 0.3333
#  - Recall: 0.2000
#
# Model 252:
#  - Run ID: dd23fe8ddbad4daa9c0b1653bd6b4b3f
#  - Model Type: None
#
# Model 253:
#  - Run ID: 1bd8990ddc2c48eea080154b98626d03
#  - Model Type: None
#
# Model 254:
#  - Run ID: 6f547ccf19724a27b999fe9e6fd600be
#  - Model Type: None
#
# Model 255:
#  - Run ID: 4dc6a4af64924d27a7c9bb0eb9c80ee8
#  - Model Type: None
#
# Model 256:
#  - Run ID: 3e5d782a089d4d84bfee96aff5f944c3
#  - Model Type: None
#
# Now rank these models from best to worst compared to the target model (2f080b7d8ddb4b1f9e7434336e4cad97). Give a short explanation.
# AI Agent Response:
#
#
# ## Step 1: Understand the given information
# We are comparing two models, A and B, based on their accuracy scores of 0.93 and 0.89 respectively.
#
# ## Step 2: Determine what makes a model "better"
# In general, when evaluating machine learning models or any predictive task, higher accuracy is generally considered better because it indicates that the model is more accurate in its predictions compared to lower-accuracy models.
#
# ## Step 3: Compare the accuracy of both models
# Model A has an accuracy of 0.93 and Model B has an accuracy of 0.89. Since 0.93 > 0.89, Model A performs better than Model B based solely on their accuracy scores.
#
# The final answer is: $\boxed{A}$
